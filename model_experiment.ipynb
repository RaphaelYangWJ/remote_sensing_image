# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
experiment_path = "Z:/Programing_Space/DS_Workspace/PhD_Research/RP1_Mamba_Unet/dataset/OpenEarthMap/OpenEarthMap_Tensors/aachen/images/aachen_1.tif.npz"

data = np.load(experiment_path)

# %%
df = data["arr_0"]

# %%
plt.imshow(
    np.transpose(df[0,:,:,:],(1,2,0)),
    )

# %%
plt.imshow(
    np.transpose(df[1,:,:,:],(1,2,0)),
)
